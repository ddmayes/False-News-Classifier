# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.utils import shuffle
from sklearn.svm import SVC
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
true_news = pd.read_csv('True.csv')
fake_news = pd.read_csv('Fake.csv')

# %%
true_news.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
true_news.insert(4, "Label", "true", True)
true_news.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date Label
# 0  December 31, 2017   true
# 1  December 29, 2017   true
# 2  December 31, 2017   true
# 3  December 30, 2017   true
# 4  December 29, 2017   true

# %%
fake_news.insert(4, "Label", "fake", True)
fake_news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date Label
# 0  December 31, 2017  fake
# 1  December 31, 2017  fake
# 2  December 30, 2017  fake
# 3  December 29, 2017  fake
# 4  December 25, 2017  fake

# %%
everything_data = true_news.append(fake_news)
everything_data.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date Label
# 0  December 31, 2017   true
# 1  December 29, 2017   true
# 2  December 31, 2017   true
# 3  December 30, 2017   true
# 4  December 29, 2017   true

# %%
everything_data = shuffle(everything_data)
everything_data.head()
# Out:
#                                                    title  \
# 11329  ONE HILARIOUS TWEET Perfectly Sums Up How Irre...
# 2923   Trump tweets mock video of himself tackling, p...
# 15347  UPDATE ON BEATING OF WHITE COP: BLACK MAN STEA...
# 9919   Immigrants in limbo as U.S. top court weighs O...
# 16406  BREAKING: MORE HACKED E-MAILS From DNC Release...
#
#                                                     text          subject  \
# 11329  Nunes dropped a bombshell that Obama admin spi...         politics
# 2923    BRIDGEWATER, N.J. (Reuters) - President Donal...     politicsNews
# 15347  UPDATE: AND SO IT BEGINS A police officer hold...         politics
# 9919   BALTIMORE (Reuters) - In the port city of Balt...     politicsNews
# 16406  It s not the first time that the name of Vladi...  Government News
#
#                   date Label
# 11329     Mar 23, 2017  fake
# 2923     July 2, 2017   true
# 15347      Aug 9, 2015  fake
# 9919   April 15, 2016   true
# 16406     Sep 13, 2016  fake

# %%
everything_data.reset_index(inplace = True, drop = True)
everything_data.head()
# Out:
#                                                title  \
# 0  ONE HILARIOUS TWEET Perfectly Sums Up How Irre...
# 1  Trump tweets mock video of himself tackling, p...
# 2  UPDATE ON BEATING OF WHITE COP: BLACK MAN STEA...
# 3  Immigrants in limbo as U.S. top court weighs O...
# 4  BREAKING: MORE HACKED E-MAILS From DNC Release...
#
#                                                 text          subject  \
# 0  Nunes dropped a bombshell that Obama admin spi...         politics
# 1   BRIDGEWATER, N.J. (Reuters) - President Donal...     politicsNews
# 2  UPDATE: AND SO IT BEGINS A police officer hold...         politics
# 3  BALTIMORE (Reuters) - In the port city of Balt...     politicsNews
# 4  It s not the first time that the name of Vladi...  Government News
#
#               date Label
# 0     Mar 23, 2017  fake
# 1    July 2, 2017   true
# 2      Aug 9, 2015  fake
# 3  April 15, 2016   true
# 4     Sep 13, 2016  fake

# %%
from sklearn.feature_extraction import text
corpus = everything_data['text']
vectorizer = text.CountVectorizer(binary=True).fit(corpus)
vectorized_text = vectorizer.transform(corpus)

# %%
TfidF = text.TfidfTransformer(norm='l1')
tfidf = TfidF.fit_transform(vectorized_text)

# %%
from sklearn.svm import LinearSVC
labels = everything_data.Label
features = tfidf
model = LinearSVC()
X_train, X_test, y_train, y_test= train_test_split(features, labels, test_size=0.33, random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# [[7518  182]
#  [ 298 6819]]
# 0.9676047782952014
